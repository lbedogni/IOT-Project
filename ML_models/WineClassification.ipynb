# %% [markdown]
# # Wine Classification

# %% [markdown]
# ### Importo le librerie

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"

import pandas as pd
import numpy as np
import tensorflow as tf
from tinymlgen import port
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split

tf.random.set_seed(1337)
np.random.seed(1337)

# %% [markdown]
# ### Carico il Dataset ed eseguo lo split

# %%
# load and split dataset into train, validation, test
x_values, y_values = load_wine(return_X_y=True)

print("Total samples: " + str(x_values.shape[0]))

y = tf.keras.utils.to_categorical(y_values)
x_train, x_test, y_train, y_test = train_test_split(x_values, y, test_size=0.2)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.3)

print("Train samples: " + str(x_train.shape))
print("Validation samples: " + str(x_valid.shape))
print("Test samples: " + str(x_test.shape))

input_dim = x_train.shape[1:]
output_dim = y.shape[1]

print("Input dimension: ", input_dim)
print("Output dimension: ", output_dim)
# Out:
# Total samples: 178
# Train samples: (99, 13)
# Validation samples: (43, 13)
# Test samples: (36, 13)
# Input dimension:  (13,)
# Output dimension:  3

# %% [markdown]
# ### Visualizzo il Dataset

# %%
data = load_wine()

# Converto data in un Dataframe per visualizzarlo correttamente
df = pd.DataFrame(data=data["data"], columns=data["feature_names"])
# Aggiungo la rispettiva classe di ogni sample
df["class"] = data["target"]

# Stampo i primi 5 sample
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols
# 0    14.23        1.71  2.43               15.6      127.0           2.80  \
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue
# 0        3.06                  0.28             2.29             5.64  1.04  \
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  class
# 0                          3.92   1065.0      0
# 1                          3.40   1050.0      0
# 2                          3.17   1185.0      0
# 3                          3.45   1480.0      0
# 4                          2.93    735.0      0

# %% [markdown]
# ### Creazione del modello

# %%
# creo e alleno il modello
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(units=20, activation="relu", input_shape=input_dim))
model.add(tf.keras.layers.Dense(units=40, activation="relu"))
model.add(tf.keras.layers.Dense(output_dim, activation="softmax"))

# uso categorical_crossentropy per la classificazione multi classe
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
model.fit(x_train, y_train, validation_data=(x_valid, y_valid), epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 98ms/step - loss: 322.7955 - accuracy: 0.4141 - val_loss: 295.3567 - val_accuracy: 0.3953
# Epoch 2/100
# 4/4 [==============================] - 0s 16ms/step - loss: 265.2348 - accuracy: 0.4141 - val_loss: 235.3179 - val_accuracy: 0.3953
# Epoch 3/100
# 4/4 [==============================] - 0s 15ms/step - loss: 210.4118 - accuracy: 0.4141 - val_loss: 176.2215 - val_accuracy: 0.3953
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 155.1409 - accuracy: 0.4141 - val_loss: 117.8649 - val_accuracy: 0.3953
# Epoch 5/100
# 4/4 [==============================] - 0s 16ms/step - loss: 101.2766 - accuracy: 0.4141 - val_loss: 60.8646 - val_accuracy: 0.3953
# Epoch 6/100
# 4/4 [==============================] - 0s 16ms/step - loss: 48.9670 - accuracy: 0.4141 - val_loss: 21.2679 - val_accuracy: 0.3721
# Epoch 7/100
# 4/4 [==============================] - 0s 15ms/step - loss: 30.1915 - accuracy: 0.3030 - val_loss: 30.7464 - val_accuracy: 0.3256
# Epoch 8/100
# 4/4 [==============================] - 0s 16ms/step - loss: 34.6243 - accuracy: 0.2727 - val_loss: 22.3410 - val_accuracy: 0.3256
# Epoch 9/100
# 4/4 [==============================] - 0s 15ms/step - loss: 20.7684 - accuracy: 0.2727 - val_loss: 4.5706 - val_accuracy: 0.5349
# Epoch 10/100
# 4/4 [==============================] - 0s 15ms/step - loss: 9.5696 - accuracy: 0.3535 - val_loss: 13.9266 - val_accuracy: 0.2791
# Epoch 11/100
# 4/4 [==============================] - 0s 15ms/step - loss: 10.9412 - accuracy: 0.3232 - val_loss: 4.7137 - val_accuracy: 0.3953
# Epoch 12/100
# 4/4 [==============================] - 0s 15ms/step - loss: 4.1079 - accuracy: 0.4949 - val_loss: 4.2018 - val_accuracy: 0.6279
# Epoch 13/100
# 4/4 [==============================] - 0s 15ms/step - loss: 6.2030 - accuracy: 0.5051 - val_loss: 5.2226 - val_accuracy: 0.5814
# Epoch 14/100
# 4/4 [==============================] - 0s 15ms/step - loss: 5.2926 - accuracy: 0.5859 - val_loss: 3.5860 - val_accuracy: 0.6512
# Epoch 15/100
# 4/4 [==============================] - 0s 16ms/step - loss: 3.3683 - accuracy: 0.5657 - val_loss: 0.8687 - val_accuracy: 0.6279
# Epoch 16/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.1927 - accuracy: 0.5960 - val_loss: 2.2722 - val_accuracy: 0.5814
# Epoch 17/100
# 4/4 [==============================] - 0s 15ms/step - loss: 2.9738 - accuracy: 0.5152 - val_loss: 2.1780 - val_accuracy: 0.5581
# Epoch 18/100
# 4/4 [==============================] - 0s 15ms/step - loss: 2.3284 - accuracy: 0.5758 - val_loss: 0.8465 - val_accuracy: 0.7907
# Epoch 19/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.7790 - accuracy: 0.6970 - val_loss: 1.8584 - val_accuracy: 0.6512
# Epoch 20/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.5837 - accuracy: 0.6566 - val_loss: 0.6208 - val_accuracy: 0.6512
# Epoch 21/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0416 - accuracy: 0.6162 - val_loss: 1.3690 - val_accuracy: 0.6047
# Epoch 22/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.8618 - accuracy: 0.6364 - val_loss: 0.8629 - val_accuracy: 0.7907
# Epoch 23/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8866 - accuracy: 0.7273 - val_loss: 1.3907 - val_accuracy: 0.6744
# Epoch 24/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.3183 - accuracy: 0.6566 - val_loss: 0.7599 - val_accuracy: 0.6744
# Epoch 25/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8272 - accuracy: 0.6465 - val_loss: 0.6422 - val_accuracy: 0.8140
# Epoch 26/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7918 - accuracy: 0.6768 - val_loss: 0.7291 - val_accuracy: 0.6977
# Epoch 27/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7673 - accuracy: 0.7071 - val_loss: 0.6748 - val_accuracy: 0.7674
# Epoch 28/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9855 - accuracy: 0.6768 - val_loss: 0.6238 - val_accuracy: 0.7442
# Epoch 29/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7167 - accuracy: 0.7172 - val_loss: 0.5717 - val_accuracy: 0.7209
# Epoch 30/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6491 - accuracy: 0.7374 - val_loss: 0.7615 - val_accuracy: 0.6512
# Epoch 31/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6699 - accuracy: 0.7172 - val_loss: 0.7772 - val_accuracy: 0.7674
# Epoch 32/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6630 - accuracy: 0.7677 - val_loss: 0.6080 - val_accuracy: 0.7442
# Epoch 33/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7811 - accuracy: 0.7172 - val_loss: 0.5867 - val_accuracy: 0.8140
# Epoch 34/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6036 - accuracy: 0.7980 - val_loss: 1.1049 - val_accuracy: 0.6744
# Epoch 35/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.8774 - accuracy: 0.7071 - val_loss: 0.6389 - val_accuracy: 0.7674
# Epoch 36/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.7014 - accuracy: 0.7273 - val_loss: 0.5143 - val_accuracy: 0.7442
# Epoch 37/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6372 - accuracy: 0.7677 - val_loss: 0.5191 - val_accuracy: 0.7907
# Epoch 38/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7098 - accuracy: 0.7273 - val_loss: 0.5474 - val_accuracy: 0.8140
# Epoch 39/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.0355 - accuracy: 0.6667 - val_loss: 0.9249 - val_accuracy: 0.6279
# Epoch 40/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9457 - accuracy: 0.6364 - val_loss: 0.9173 - val_accuracy: 0.6977
# Epoch 41/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.9396 - accuracy: 0.6566 - val_loss: 0.6581 - val_accuracy: 0.7907
# Epoch 42/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6296 - accuracy: 0.7374 - val_loss: 0.4911 - val_accuracy: 0.7674
# Epoch 43/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7014 - accuracy: 0.7273 - val_loss: 0.6212 - val_accuracy: 0.8372
# Epoch 44/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5789 - accuracy: 0.7576 - val_loss: 0.6110 - val_accuracy: 0.7907
# Epoch 45/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5105 - accuracy: 0.8081 - val_loss: 0.5310 - val_accuracy: 0.7907
# Epoch 46/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5163 - accuracy: 0.7980 - val_loss: 0.4898 - val_accuracy: 0.7907
# Epoch 47/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4956 - accuracy: 0.8081 - val_loss: 0.5429 - val_accuracy: 0.8140
# Epoch 48/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4925 - accuracy: 0.8081 - val_loss: 0.6322 - val_accuracy: 0.7674
# Epoch 49/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5579 - accuracy: 0.7677 - val_loss: 0.5778 - val_accuracy: 0.8140
# Epoch 50/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6711 - accuracy: 0.7273 - val_loss: 0.5643 - val_accuracy: 0.8140
# Epoch 51/100
# 4/4 [==============================] - 0s 53ms/step - loss: 0.6659 - accuracy: 0.7071 - val_loss: 0.6335 - val_accuracy: 0.6512
# Epoch 52/100
# 4/4 [==============================] - 0s 41ms/step - loss: 0.8178 - accuracy: 0.6465 - val_loss: 0.4874 - val_accuracy: 0.8140
# Epoch 53/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5960 - accuracy: 0.7273 - val_loss: 0.6379 - val_accuracy: 0.7907
# Epoch 54/100
# 4/4 [==============================] - 0s 23ms/step - loss: 0.6069 - accuracy: 0.7273 - val_loss: 0.4576 - val_accuracy: 0.7674
# Epoch 55/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4726 - accuracy: 0.7980 - val_loss: 1.1480 - val_accuracy: 0.6512
# Epoch 56/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.9042 - accuracy: 0.6768 - val_loss: 0.4431 - val_accuracy: 0.8140
# Epoch 57/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7419 - accuracy: 0.7172 - val_loss: 0.6284 - val_accuracy: 0.7907
# Epoch 58/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6305 - accuracy: 0.7374 - val_loss: 0.7924 - val_accuracy: 0.7442
# Epoch 59/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6891 - accuracy: 0.7172 - val_loss: 0.6374 - val_accuracy: 0.8372
# Epoch 60/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6684 - accuracy: 0.7374 - val_loss: 0.4801 - val_accuracy: 0.8372
# Epoch 61/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4656 - accuracy: 0.8081 - val_loss: 0.6404 - val_accuracy: 0.7907
# Epoch 62/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.5083 - accuracy: 0.7879 - val_loss: 0.5679 - val_accuracy: 0.8372
# Epoch 63/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5115 - accuracy: 0.7677 - val_loss: 0.5072 - val_accuracy: 0.8140
# Epoch 64/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5400 - accuracy: 0.7677 - val_loss: 0.5581 - val_accuracy: 0.8140
# Epoch 65/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.4577 - accuracy: 0.7879 - val_loss: 0.4913 - val_accuracy: 0.8372
# Epoch 66/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4483 - accuracy: 0.8384 - val_loss: 0.4412 - val_accuracy: 0.8140
# Epoch 67/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.7341 - accuracy: 0.7475 - val_loss: 0.4209 - val_accuracy: 0.8372
# Epoch 68/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4880 - accuracy: 0.7879 - val_loss: 0.8378 - val_accuracy: 0.7209
# Epoch 69/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6768 - accuracy: 0.6869 - val_loss: 0.5064 - val_accuracy: 0.8140
# Epoch 70/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6159 - accuracy: 0.7576 - val_loss: 0.4755 - val_accuracy: 0.8140
# Epoch 71/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4421 - accuracy: 0.8485 - val_loss: 0.7633 - val_accuracy: 0.7442
# Epoch 72/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5619 - accuracy: 0.7980 - val_loss: 0.5519 - val_accuracy: 0.8140
# Epoch 73/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5477 - accuracy: 0.7475 - val_loss: 0.4122 - val_accuracy: 0.8605
# Epoch 74/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6533 - accuracy: 0.7273 - val_loss: 0.5362 - val_accuracy: 0.8372
# Epoch 75/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3788 - accuracy: 0.8687 - val_loss: 0.6518 - val_accuracy: 0.7674
# Epoch 76/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.4587 - accuracy: 0.8081 - val_loss: 0.5237 - val_accuracy: 0.8140
# Epoch 77/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5053 - accuracy: 0.7576 - val_loss: 0.4486 - val_accuracy: 0.8605
# Epoch 78/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5375 - accuracy: 0.7879 - val_loss: 0.4492 - val_accuracy: 0.8372
# Epoch 79/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4198 - accuracy: 0.8485 - val_loss: 0.4917 - val_accuracy: 0.8140
# Epoch 80/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5338 - accuracy: 0.7778 - val_loss: 0.4465 - val_accuracy: 0.8140
# Epoch 81/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5283 - accuracy: 0.7677 - val_loss: 0.4702 - val_accuracy: 0.8372
# Epoch 82/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5272 - accuracy: 0.7576 - val_loss: 0.5577 - val_accuracy: 0.8372
# Epoch 83/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.5066 - accuracy: 0.7778 - val_loss: 0.3942 - val_accuracy: 0.8837
# Epoch 84/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5677 - accuracy: 0.7374 - val_loss: 0.4151 - val_accuracy: 0.8605
# Epoch 85/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4539 - accuracy: 0.7980 - val_loss: 0.8514 - val_accuracy: 0.6977
# Epoch 86/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.6158 - accuracy: 0.7172 - val_loss: 0.6408 - val_accuracy: 0.8140
# Epoch 87/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.5387 - accuracy: 0.8081 - val_loss: 0.6435 - val_accuracy: 0.7209
# Epoch 88/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.6304 - accuracy: 0.6869 - val_loss: 0.4115 - val_accuracy: 0.8372
# Epoch 89/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4041 - accuracy: 0.8182 - val_loss: 0.4644 - val_accuracy: 0.8372
# Epoch 90/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4840 - accuracy: 0.7980 - val_loss: 0.4323 - val_accuracy: 0.8372
# Epoch 91/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3870 - accuracy: 0.8586 - val_loss: 0.4390 - val_accuracy: 0.8605
# Epoch 92/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3492 - accuracy: 0.8687 - val_loss: 0.4562 - val_accuracy: 0.8605
# Epoch 93/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3447 - accuracy: 0.8990 - val_loss: 0.4392 - val_accuracy: 0.9070
# Epoch 94/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3417 - accuracy: 0.8788 - val_loss: 0.4992 - val_accuracy: 0.8372
# Epoch 95/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4925 - accuracy: 0.7778 - val_loss: 0.4469 - val_accuracy: 0.8605
# Epoch 96/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.4373 - accuracy: 0.8182 - val_loss: 0.4079 - val_accuracy: 0.8837
# Epoch 97/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3400 - accuracy: 0.8990 - val_loss: 0.4502 - val_accuracy: 0.8605
# Epoch 98/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3373 - accuracy: 0.9091 - val_loss: 0.4415 - val_accuracy: 0.8372
# Epoch 99/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.3608 - accuracy: 0.8687 - val_loss: 0.4222 - val_accuracy: 0.9070
# Epoch 100/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.3460 - accuracy: 0.8687 - val_loss: 0.4097 - val_accuracy: 0.8837

# %% [markdown]
# ### Accuratezza del modello

# %%
print("Accuracy: %.3f" % model.evaluate(x_test, y_test)[1])
# Out:
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8528 - accuracy: 0.7778
# Accuracy: 0.778

# %% [markdown]
# ### Seleziono un sample dal Dataset di test da salvare nel file header

# %%
cpp_dataset_variables = ""

# seleziono il primo sample del test set
first_sample_x = x_test[0]
first_sample_y = y_test[0]

cpp_dataset_variables = "float x_test[13] = "
x_values_str = str([ x for x in first_sample_x ])
x_values_str = x_values_str.replace("[", "{ ")
x_values_str = x_values_str.replace("]", " };\n")

cpp_dataset_variables += x_values_str

# seleziono l'indice dove è presente il valore 1. nell'array delle classi y reali
cpp_dataset_variables += "const int y_test = " + str(np.where(first_sample_y == 1.)[0][0]) + ";"

print(cpp_dataset_variables)
# Out:
# float x_test[13] = { 13.05, 1.77, 2.1, 17.0, 107.0, 3.0, 3.0, 0.28, 2.03, 5.04, 0.88, 3.35, 885.0 };
# const int y_test = 0;

# %% [markdown]
# ### Salvo il modello nel file header

# %%
cpp_code = port(model, variable_name="WineClassificationModel", pretty_print=True, optimize=False)

cpp_code += "\n"
cpp_code = cpp_code + cpp_dataset_variables

# cpp files
with open("assets/cpp_files/WineClassification.h", "w+") as f:
    f.write(cpp_code)
    
# esp32
with open("../WineClassification/WC_ESP32/include/WineClassification.h", "w+") as f:
    f.write(cpp_code)

# esp8266
with open("../WineClassification/WC_ESP8266/include/WineClassification.h", "w+") as f:
    f.write(cpp_code)

# wemos
with open("../WineClassification/WC_WEMOS/include/WineClassification.h", "w+") as f:
    f.write(cpp_code)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/k6/0tv_bzp937scnn3d7yzhy1vr0000gn/T/tmpx0cpgfxy/assets
# INFO:tensorflow:Assets written to: /var/folders/k6/0tv_bzp937scnn3d7yzhy1vr0000gn/T/tmpx0cpgfxy/assets

# %% [markdown]
# ### Previsione di un singolo sample

# %%
print(model.predict(x_test[0:1]))
print(y_test[0:1])
# Out:
# 1/1 [==============================] - 1s 684ms/step
# [[0.63433325 0.09378678 0.27187997]]
# [[1. 0. 0.]]
